# %%
import numpy as np
import pandas as pd
# %matplotlib inline 
import matplotlib.pyplot as plt
import scipy.stats as stats
import random
import math
import seaborn as sns
import statsmodels.api as sm

import warnings 
warnings.filterwarnings('ignore')

color = sns.color_palette()
sns.set_style('darkgrid')

# %% [markdown]
# Visualisierung

# %%
df1 = pd.read_csv('data/Beispielsdaten/2024_10_07_13_14_55_96000Hz.csv')
df2 = pd.read_csv('data/Beispielsdaten/2024_10_07_13_16_03_96000Hz.csv')
df3 = pd.read_csv('data/Beispielsdaten/2024_10_07_13_16_21_96000Hz.csv')
df1.head()
# Out:
#     # Audio    Voltage   Current
# 0  1.743164  17.960386  0.524393
# 1  1.752930  17.960386  0.304667
# 2  1.762695  17.960386  0.524393
# 3  1.762695  17.972488  0.377909
# 4  1.767578  17.960386  0.451151

# %% [markdown]
# Vergleich von 3 unterschiedlichen Beispieldatensätze

# %%
#Jeder 5-te Datenpunkt genommen zur besseren Lesbarkeit

df1[::5].plot()
df2[::5].plot()
df3[::5].plot()
# Out:
# <Axes: >

# %% [markdown]
# Statistische Kennzahlen

# %%
print(f'Dataframe 1 Minimum:\n {df1.min()}\n')
print(f'Dataframe 1 Maximum:\n {df1.min()}\n\n')
print(f'Dataframe 2 Minimum:\n {df1.min()}\n')
print(f'Dataframe 2 Maximum:\n {df1.min()}\n\n')
print(f'Dataframe 3 Minimum:\n {df1.min()}\n')
print(f'Dataframe 3 Maximum:\n {df1.min()}\n')
# Out:
# Dataframe 1 Minimum:
#  # Audio     0.522461
# Voltage    11.848530
# Current     0.011698
# dtype: float64
#
# Dataframe 1 Maximum:
#  # Audio     0.522461
# Voltage    11.848530
# Current     0.011698
# dtype: float64
#
#
# Dataframe 2 Minimum:
#  # Audio     0.522461
# Voltage    11.848530
# Current     0.011698
# dtype: float64
#
# Dataframe 2 Maximum:
#  # Audio     0.522461
# Voltage    11.848530
# Current     0.011698
# dtype: float64
#
#
# Dataframe 3 Minimum:
#  # Audio     0.522461
# Voltage    11.848530
# Current     0.011698
# dtype: float64
#
# Dataframe 3 Maximum:
#  # Audio     0.522461
# Voltage    11.848530
# Current     0.011698
# dtype: float64
